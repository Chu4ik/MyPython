# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://24score.pro/football/england/premier_league/2024-2025/regular_season/fixtures/'

# %%
response = requests.get(url)

if response.status_code == 200: # Получите HTML-код страницы 
    html_content = response.text # Используйте BeautifulSoup для парсинга HTML 
    soup = BeautifulSoup(html_content, 'html.parser') # Выведите HTML-код 
    print(soup.prettify()) 
else: 
    print(f'Ошибка при запросе страницы: {response.status_code}')
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Матчи чемпионата, игры в туре, расписание игр, статистика встреч, результаты матчей, игры дома в гостях. " name="description"/>
#   <meta content="" name="keywords"/>
#   <meta content="YAhtYNtqi6PMmexRuCLZCeSz9MbnaFNlrbk-dzVvMSs" name="google-site-verification"/>
#   <meta content="0433ab40f05f200e" name="yandex-verification"/>
#   <title>
#    Результаты матчей чемпионата Англии по футболу Премьер-лига 2024/25 - 24score.pro
#   </title>
#   <link href="/templates/new24score/main2.css?p=10" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/templates/new24score/page.css?p=10" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/templates/new24score/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <script src="/js/jquery.js" type="text/javascript">
#   </script>
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL для запроса данных (замените на реальный URL)
url = 'https://24score.pro/football/england/premier_league/2024-2025/regular_season/fixtures/'  # пример URL

# Отправка GET-запроса
response = requests.get(url)

# Проверка успешности запроса
if response.status_code == 200:
    # Разбор HTML-кода
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Поиск всех таблиц
    tables = soup.find_all('table')
    print(f'Найдено таблиц: {len(tables)}')
    
    # Вывод HTML-кода каждой таблицы
    for table in tables:
        print(table.prettify())
else:
    print(f'Ошибка при запросе страницы: {response.status_code}')
# Out:
# Найдено таблиц: 0
